# %%
import string

# %%
unicode_encoding = ord('a')
print(unicode_encoding)
unicode_decoding = chr(unicode_encoding)
print(unicode_decoding)
# Out:
# 97
# a

# %%
chr(123)
# Out:
# '{'

# %%
emoji = "🇺🇸"

# %%
"🇺🇸".encode()
# Out:
# b'\xf0\x9f\x87\xba\xf0\x9f\x87\xb8\xf0\x9f\x9a\xa9'

# %%
"🚩".encode()
# Out:
# b'\xf0\x9f\x9a\xa9'

# %%
"🏁".encode()
# Out:
# b'\xf0\x9f\x8f\x81'

# %%
hex(127937)
# Out:
# '0x1f3c1'

# %%
127937

# %%
chr(127937)
# Out:
# '🏁'

# %%
ord("🏁")
# Out:
# 127937

# %%
"a".encode()
# Out:
# b'a'

# %%
"🇺🇸🚩🏁".encode()
# Out:
# b'\xf0\x9f\x87\xba\xf0\x9f\x87\xb8\xf0\x9f\x9a\xa9\xf0\x9f\x8f\x81'

# %%
2**16
# Out:
# 65536

# %%
b'\xe0\xa4\x8f'.decode()
# Out:
# 'ए'

# %%
emoji.encode()
# Out:
# b'\xf0\x9f\x98\x82'

# %%
enc_emoji = b'\xf0\x9f\x98\x82'
enc_emoji.decode()
# Out:
# '😂'

# %%
for i in range(10):
    print(chr(i))

# %%
char = chr(1)
print(char)

# %%
character = "a"
character.encode('utf-8')
# Out:
# b'a'
